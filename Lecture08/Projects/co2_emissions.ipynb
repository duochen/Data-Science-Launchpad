# %% [markdown]
# # Project 2: Predicting CO₂ Emissions with Polynomial Regression
#
# ## Description:
# Estimate CO₂ emissions based on car engine size.
#
# ## Dataset:
# Use [Fuel Consumption CO₂ dataset from Canada](https://www.kaggle.com/datasets/debajyotipodder/co2-emission-by-vehicles)
#
# ## Concepts:
# - Polynomial regression (degree 2 or 3)
# - Model fitting and plotting
# - R² for model evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
# 1. Load dataset
data = pd.read_csv("co2_emissions.csv")
X = data[["Engine Size(L)"]]
y = data["CO2 Emissions(g/km)"]

# %%
# 2. Polynomial features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
# 3. Train model
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# 4. Predict
y_pred = model.predict(X_poly)

# %%
# 5. Evaluate
r2 = r2_score(y, y_pred)
print(f"R²: {r2:.2f}")
# Out:
# R²: 0.73

# %%
# 6. Plot
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', label='Polynomial Fit')
plt.xlabel("Engine Size")
plt.ylabel("CO₂ Emissions")
plt.legend()
plt.title("Polynomial Regression: Engine Size vs CO₂ Emissions")
plt.show()

# %% [markdown]
# ## 🖼️ Visualization: **Polynomial Regression - Engine Size vs CO₂ Emissions**
#
# ### 📊 What You See:
#
# * A 2D **scatter plot** and **curve**:
#
#   * **Blue dots**: Actual CO₂ emissions for each vehicle (raw data points)
#   * **Red curve**: The polynomial regression model's fitted curve (degree 2)
#
# ---
#
# ## 🔍 How to Interpret:
#
# ### ✅ Good Fit:
#
# * If the red curve closely follows the **general shape of the blue dots**, it means the model is doing a good job capturing the relationship between engine size and CO₂ emissions.
# * A curved line shows that the relationship is **nonlinear** (not a straight line).
#
# ### ⚠️ Poor Fit:
#
# * If the red curve **doesn’t match the trend** of the blue dots or misses large areas of data, the model may be underfitting or the data may need a different polynomial degree.
#
# ---
#
# ## 📈 Evaluation Metric:
#
# ### **R² (R-squared Score)**:
#
# * Tells how well the model explains the variance in the target (`CO₂ Emissions`)
# * **Ranges**:
#
#   * **1.0** = perfect fit
#   * **0.0** = model explains none of the variance
#   * **> 0.8** is usually considered a good fit
# * Example: `R²: 0.95` means 95% of the variation in CO₂ emissions is explained by engine size using this model.
#
# ---
#
# ## 🧠 Summary:
#
# | Aspect                   | Interpretation                                          |
# | ------------------------ | ------------------------------------------------------- |
# | Scatter Plot (blue dots) | Actual CO₂ emissions vs. engine size                    |
# | Red Curve                | Model's predicted CO₂ emissions (2nd-degree polynomial) |
# | Curve fits dots well     | Polynomial regression captured the nonlinear pattern    |
# | R² Score                 | High score = strong relationship modeled                |
