# %% [markdown]
# Visualization with Seaborn
# https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
# Plot with seaborn
import seaborn as sns
sns.set()

# %%
# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
# Histograms, KDE and densities
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], density=True, alpha=0.5)

# %%
# Plot with seaborn
import seaborn as sns
for col in 'xy':
    sns.kdeplot(data[col], shade=True)
# Out:
# C:\Users\dchen\AppData\Local\Temp\ipykernel_34392\3305066218.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# C:\Users\dchen\AppData\Local\Temp\ipykernel_34392\3305066218.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)

# %%
# Plot with seaborn
import seaborn as sns
sns.distplot(data['x'])
sns.distplot(data['y']);
# Out:
# C:\Users\dchen\AppData\Local\Temp\ipykernel_34392\2245168485.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['x'])
# C:\Users\dchen\AppData\Local\Temp\ipykernel_34392\2245168485.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['y']);

# %%
# Plot with seaborn
import seaborn as sns
sns.kdeplot(data);

# %%
# Correct jointplot with keyword arguments
import seaborn as sns
import numpy as np
import pandas as pd
x = np.random.randn(100)
y = 2 * x + np.random.randn(100)
data = pd.DataFrame({'x': x, 'y': y})
with sns.axes_style('white'):
    sns.jointplot(x='x', y='y', data=data, kind='kde')

# %%
# Correct jointplot with keyword arguments
import seaborn as sns
import numpy as np
import pandas as pd
x = np.random.randn(100)
y = 2 * x + np.random.randn(100)
data = pd.DataFrame({'x': x, 'y': y})
with sns.axes_style('white'):
    sns.jointplot(x='x', y='y', data=data, kind='kde')

# %%
# Plot with seaborn
import seaborn as sns
# Pair plots
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Load iris dataset and plot pairplot
import seaborn as sns
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue='species', height=2.5)

# %%
# Plot with seaborn
import seaborn as sns
# Faceted histograms
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Plot with seaborn
import seaborn as sns
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));

# %%
# Load tips dataset and plot catplot (box)
import seaborn as sns
tips = sns.load_dataset('tips')
with sns.axes_style('ticks'):
    g = sns.catplot(x='day', y='total_bill', hue='sex', data=tips, kind='box')
    g.set_axis_labels('Day', 'Total Bill')
